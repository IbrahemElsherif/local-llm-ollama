# %%
# !winget install llama.cpp
# Out:
# 'winget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from llama_cpp import Llama
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from llama_cpp import Llama
#
# ModuleNotFoundError: No module named 'llama_cpp'

# %%
llm = Llama(
    model_path="E:\Machine Learning\CodE\local-llm-ollama\Meta-Llama-3.1-8B-q4_k_m-paul-graham-guide-GGUF\Meta-Llama-3.1-8B-Instruct.Q4_K_M.gguf"
)

# %%
llm.create_chat_completion(
      messages = [
        {"role": "user", "content": "Who are you?"},
      ]
)

# %%
print(llm.chat_format)  # This might return "llama-2", "mistral", "chatml", or something else.
